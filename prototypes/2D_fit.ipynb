# %%
# %autoreload 2  
# %matplotlib inline

# %%
import numpy as np 
import matplotlib.pyplot as plt
import sys
sys.path.append("../")
import triangle

# %%
import sample_and_fit_gp as sam
import diag_plots as dplot

# %%
np.random.seed(1)  # fix the random seed for reproducibility

# %%
truth = [1.5, .5]  # right now uses George's parametrization
spacing = 5.
rng = (0, 60.)
noise_amp = 1e-4

# %% [markdown]
# parametrization of the Sq Exp kernel in George is:
# \begin{equation}
# k(r_{ij}) = \theta_1 \exp\left(\frac{r_{ij}^2 }{ 2. \theta_2^2}\right)
# \end{equation}
#
# Our parametrization has the restriction of:

# %%
coords, psi, psi_err = \
    sam.generate_2D_data(truth, spacing, rng, noise_amp)

# %% [markdown]
# check that our drawn data points are not crazy

# %%
dplot.plot_2D_gp_samples(psi, coords, figside=6, 
                         truth=truth, range_No=rng[1])

# %%
np.log(truth)
# Out:
# array([ 0.40546511, -0.69314718])

# %%
data = (coords, psi, psi_err)
prior_vals = [[1, 2],[0, 1]]

# %% [markdown]
# make sure that I didn't put in stupid prior

# %%
assert sam.lnprior_gp(truth, prior_vals=prior_vals) is not -np.inf,\
    "invalid prior choice"

# %%
sampler, p0 = sam.fit_gp(truth, data, guess_dev_frac=1e-1,
                         prior_vals=prior_vals, nwalkers=4,
                         a=3.5)
# Out:
# Initial guesses were [ 1.5676926  0.415797 ]
# Initial guesses were [ 1.32597448  0.56750534]
# Initial guesses were [ 1.45030752  0.51932696]
# Initial guesses were [ 1.37228165  0.55004407]
# Running burn-in with length 1000
# Running second burn-in with length 1000
# Running production chain with length 5000
# the optimized p0 values are
# [[ 1.25219199  0.56783986]
#  [ 1.16014249  0.2616748 ]
#  [ 1.15904192  0.10086472]
#  [ 1.246468    0.48731962]]

# %% [markdown]
# # plot properties

# %%
labels = [r"$\theta_1$", r"$\theta_2^2$"]

# %% [markdown]
# # visualize the trace plots

# %%
dplot.trace_plot(sampler, labels, truth)

# %% [markdown]
# # visualize the 68% and 95% credible contours

# %%
dplot.N_by_N_lower_triangle_plot(
    sampler.flatchain.transpose(), 0.05, [0, 1], 
    truth=truth,
    axlabels=labels,
    N_bins=[50, 50])
# Out:
# N_bins = 50
# N_bins = 50
