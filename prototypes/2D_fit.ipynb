# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2  
# %matplotlib inline

# %% [markdown]
# This notebook demonstrates the fitting of a 2D Gaussian random field

# %%
from __future__ import print_function
import numpy as np 
import matplotlib.pyplot as plt
import sys
sys.path.append("../")
import triangle
import george
from george import kernels
from IPython.html.widgets import interact

# %%
import sample_and_fit_gp as sam
import diag_plots as dplot

# %%
np.random.seed(1)  # fix the random seed for reproducibility

# %%
truth = [1.5, .5]  # right now uses George's parametrization
spacing = 5.
rng = (0, 100.)
noise_amp = 1e-1

# %% [markdown]
# parametrization of the Sq Exp kernel in George is:
# \begin{equation}
# k(r_{ij}) = \theta_1 \exp\left(\frac{r_{ij}^2 }{ 2. \theta_2^2}\right)
# \end{equation}
#
# Our parametrization has the restriction of:

# %%
coords, psi, psi_err = \
    sam.generate_2D_data(truth, spacing, rng, noise_amp)

# %% [markdown]
# check that our drawn data points are not crazy

# %%
dplot.plot_2D_gp_samples(psi, coords, figside=6, 
                         truth=truth, range_No=rng[1])

# %% [markdown]
# # set prior in log scale!!! very important

# %%
lnHP_truth = list(np.log(truth[:2])) + truth[2:]
print(lnHP_truth)
# Out:
# [0.40546510810816438, -0.69314718055994529]

# %% [markdown]
# try to initialize a broad prior

# %%
lnprior_vals = np.array([[-5, 5], [-5, 5.]])

# %%
data = (coords, psi, psi_err)

# %% [markdown]
# make sure that I didn't put in unreasonable prior

# %%
assert sam.lnprior_gp(truth, lnprior_vals=lnprior_vals) is not -np.inf,\
    "invalid prior choice"

# %% [markdown]
# # first use the results optimized by george as initial starting location

# %% [markdown]
# # test how initial locations of the chains affect the results

# %%
# the proposal scale parameter a = 2.0 by default, I have hard tuned this 
# so the acceptance fraction 0.2 < a_f < 0.5
# maybe tuning a wszis not the best thing to do

# %%
# %time sampler, p0 = sam.fit_gp(lnHP_truth, data, guess_dev_frac=1e-3, lnprior_vals=lnprior_vals, nwalkers=8, a=3.5, threads=4, burnin_chain_len=int(1e2), conver_chain_len=1000)
# Out:
# Initial guesses were [ 1.50058777  0.49974848]
# Initial guesses were [ 1.50202123  0.50020807]
# Initial guesses were [ 1.4997692   0.50035183]
# Initial guesses were [ 1.50026519  0.50023832]
# Initial guesses were [ 1.49835976  0.50042069]
# Initial guesses were [ 1.50004394  0.49965016]
# Initial guesses were [ 1.49905337  0.5002123 ]
# Initial guesses were [ 1.49991525  0.50025256]
# Running burn-in with length 100
# Running second burn-in with length 100
# Running production chain with length 1000
# the optimized p0 values are
# [[ 0.44759198  0.26204207]
#  [ 0.35279398 -0.58725994]
#  [ 0.28589259 -3.82278205]
#  [ 0.26192432 -2.27353073]
#  [ 0.34101908 -0.69100139]
#  [ 0.23208853  0.11123122]
#  [ 0.38574609 -3.99254532]
#  [ 0.3376418  -4.35466226]]
# CPU times: user 1.63 s, sys: 149 ms, total: 1.78 s
# Wall time: 1min 10s

# %% [markdown]
# # plot properties

# %%
labels = [r"$\ln\,\theta_1$", r"$\ln\,\theta_2^2$"]

# %% [markdown]
# # visualize the trace plots

# %%
dplot.trace_plot(sampler, labels, np.log(truth))

# %% [markdown]
# -[x] burn in seems adequate
# -[x] chains seem to have converged

# %% [markdown]
# # visualize the 68% and 95% credible contours

# %%
est = dplot.N_by_N_lower_triangle_plot(
        sampler.flatchain.transpose(), 0.05, [0, 1], 
        truth=np.log(truth),  # have to be aware of if we take log or not 
        axlabels=labels,
        N_bins=[50, 50])
# Out:
# N_bins = 50
# N_bins = 50

# %% [markdown]
# # Compute likelihood of fit using George

# %%
samples.transpose()[1]
# Out:
# 8000

# %%
samples = sampler.flatchain
ix = [np.random.randint(len(samples)) for i in range(10)]
for i in range(10):
    hp = np.exp(samples[ix[i]])

# %% [markdown]
# # Project data points and show fit

# %% [markdown]
# draw random samples in the chains and compute the fit

# %%
samples = sampler.flatchain  # still in log space

# %%
np.log(truth)

# %%
lnprior_vals

# %% [markdown]
# # make use of the built in function for checking performance

# %%
ix = [np.random.randint(len(samples)) for i in range(10)]

for i in ix:
    hp = np.exp(samples[i])
    gp = george.GP(hp[0] * kernels.ExpSquaredKernel(hp[1], ndim=2))
    gp.compute(coords, psi_err)
    print("hp = ({1}, {2}); lnlikelihood of fit is {0}".format(gp.lnlikelihood(psi), *hp))

# %% [markdown]
# # try using the true params to compute the marginal likelihood instead

# %%
hp = truth
gp = george.GP(hp[0] * kernels.ExpSquaredKernel(hp[1], ndim=2))
gp.compute(coords, psi_err)
print("hp = ({1}, {2}) lnlikelihood of fit is {0}".format(gp.lnlikelihood(psi), *hp))

# %% [markdown]
# # try a bunch of ridiculous parameter values

# %%
rid = [(10, 100), (1000, 50), (0.1, 0.2), (.3, 10)]
for hp in rid: 
    gp = george.GP(hp[0] * kernels.ExpSquaredKernel(hp[1], ndim=2))
    gp.compute(coords, psi_err)
    print("hp = ({1}, {2}) lnlikelihood of fit is {0}".format(gp.lnlikelihood(psi), *hp))

# %%
fine_spacing = 1.
fine_coords = sam.make_grid(rng, fine_spacing)
# use 10 realizations from the conditional distribution

cond_preds = map(lambda x: sam.draw_cond_pred(numpy.exp(samples[x]), fine_coords, 
                psi, psi_err, coords), 
                ix)

# %%
x_coord = range(int(rng[0]), int(rng[1]), int(spacing))
y_coord = x_coord

fine_x_coord = range(int(rng[0]), int(rng[1]), int(fine_spacing))
fine_y_coord = fine_x_coord

psi_2D = psi.reshape(rng[1] / spacing, rng[1] / spacing)
psi_err_2D = \
    psi_err.reshape(rng[1] / spacing, rng[1] / spacing)
    
cond_preds_2D = \
    [pred.reshape(rng[1] / fine_spacing, rng[1] / fine_spacing) for
     pred in cond_preds]

# %%
def change_x_ix(x_ix):
    plt.title("examining column {0}".format(x_ix))
    plt.errorbar(y_coord, psi_2D.transpose()[x_ix] , 
                 yerr=psi_err_2D[:][x_ix],
             marker='.', ls="None", color='k')
    fine_x_ix = int(spacing / fine_spacing * x_ix)
    for i in range(10):
        plt.plot(fine_y_coord, cond_preds_2D[i].transpose()[fine_x_ix], 
                 color='b', alpha=0.2)
    plt.ylabel(r"$\psi$", size=14)
    plt.xlabel("y", size=14)
    plt.xlim(rng[0]-spacing, rng[1])
    return

def change_y_ix(y_ix):
    plt.title("examining row {0}".format(y_ix))
    plt.errorbar(x_coord, psi_2D[y_ix][:] , yerr=psi_err_2D[y_ix][:],
             marker='.', ls="None", color='k')
    fine_y_ix = int(spacing / fine_spacing * y_ix)
    for i in range(10):
        plt.plot(fine_x_coord, cond_preds_2D[i][fine_y_ix][:], 
                 color='b', alpha=0.2)
    plt.ylabel(r"$\psi$", size=16)
    plt.xlabel("x", size=14)
    plt.xlim(rng[0]-spacing, rng[1])
    return

# %%
interact(change_x_ix, x_ix=(0, int(rng[1] / spacing - 1), 1))

# %%
interact(change_y_ix, y_ix=(0, int(rng[1] / spacing - 1), 1))
